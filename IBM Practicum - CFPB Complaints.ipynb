# %% [markdown]
# ### Import Relevant Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### Generate Master DF

# %%
master_df = pd.read_csv('Consumer_Complaints.csv')
# Out:
# /Users/seanmcalevey/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5,6,11,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
master_df.head()
# Out:
#   Date received                                            Product  \
# 0    10/01/2019          Payday loan, title loan, or personal loan
# 1    10/01/2019                                    Debt collection
# 2    10/01/2019                                    Debt collection
# 3    10/01/2019  Credit reporting, credit repair services, or o...
# 4    10/01/2019                                    Debt collection
#
#         Sub-product                                 Issue  \
# 0  Installment loan           Struggling to pay your loan
# 1        Other debt    False statements or representation
# 2         Auto debt       Written notification about debt
# 3  Credit reporting  Incorrect information on your report
# 4      Medical debt     Attempts to collect debt not owed
#
#                                            Sub-issue  \
# 0                                                NaN
# 1                  Attempted to collect wrong amount
# 2  Notification didn't disclose it was an attempt...
# 3                      Account information incorrect
# 4                                  Debt is not yours
#
#   Consumer complaint narrative  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              Company public response  \
# 0  Company believes it acted appropriately as aut...
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3                                                NaN
# 4  Company disputes the facts presented in the co...
#
#                                         Company State ZIP code           Tags  \
# 0                    Atlas Credit Company, Inc.    TX    75703            NaN
# 1                               ProCollect, Inc    TX    79936  Servicemember
# 2                     NAVY FEDERAL CREDIT UNION    CA    91915            NaN
# 3               OKLAHOMA STUDENT LOAN AUTHORITY    IN    47130            NaN
# 4  Eastern Account Systems of Connecticut, Inc.    CT    06401            NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           10/01/2019
# 1       Consent not provided           Web           10/01/2019
# 2                        NaN           Web           10/01/2019
# 3                        NaN           Web           10/01/2019
# 4                      Other           Web           10/01/2019
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2                  In progress              Yes                NaN
# 3      Closed with explanation              Yes                NaN
# 4      Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       3391722
# 1       3391649
# 2       3391379
# 3       3391378
# 4       3391434

# %% [markdown]
# ### Import TfidfVectorizer to get Word Vectors for Every Issue

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %%
response = vectorizer.fit_transform(master_df.Issue.unique())

# %%
vec_df = pd.DataFrame(response.toarray(), columns=vectorizer.get_feature_names())

# %% [markdown]
# ### Import PCA to reduce dimensionality for proper clustering

# %%
from sklearn.decomposition import PCA

# %%
explained_variance = []

for component in range(100,2,-1):
    
    n_components = component

    vectors = vec_df.values

    pca = PCA(n_components)

    dim_reduction = pca.fit_transform(vectors)

    explained_variance.append(sum(pca.explained_variance_ratio_)*100)

# %%
n_components = 50

vectors = vec_df.values

pca = PCA(n_components)

dim_reduction = pca.fit_transform(vectors)

explained_var = round(100*sum(pca.explained_variance_ratio_), 3)

print(explained_var, '%')
# Out:
# 71.492 %

# %% [markdown]
# ### Import KMeans to Cluster the Reduced Vectors

# %%
from sklearn.cluster import KMeans

# %%
cluster_score = []

for cluster in range(20,2,-1):
    
    num_clusters = cluster
    
    kmeans = KMeans()
    
    clusters = kmeans.fit_predict(dim_reduction)
    
    cluster_score.append((cluster, kmeans.inertia_))

# %%
num_clusters = 50

n_init = 500
    
kmeans = KMeans(num_clusters, n_init=n_init, random_state=18)
    
clusters = kmeans.fit_predict(dim_reduction)

print(clusters)
# Out:
# [ 2  7 47 14 36 32 35 40 25 33 27 21  4  7 28 13  2 37  1 21  7  5  1 17
#  42  0 10 32  9 40  1 41 29 18 24 28 39 12 43  6 42 10 49 48  7 13 31  4
#  15 10  2 46  9 29 20  7 20 29 44  6 29 26  3 48 22 26  9  0 15 30 13 22
#   4 30 16 34 45 19 34  0 11 23  6 10 14  7 37 49  7 28 38 44 17 32 36 47
#  25 48 28 10 33 24 20 42 46  7  8 27 47 40  5  0 48  1 21 33  8 40 35 19
#  45  0 37  0  4 43 12  4 27 26  3  7 21 15  0 44 43 22  3 41 41 18 31 49
#  49  7  7  7  7 24 24 39 13  7  8 19 16 13 16 23 23 11  5 38 38  0]

# %%
cluster_df = pd.DataFrame(clusters)

cluster_df['Issue'] = master_df.Issue.unique()

# %%
cluster_df.columns = ['Cluster', 'Issue']

# %%
cluster_df = cluster_df.sort_values('Cluster')

# %%
cluster_df.head(25)
# Out:
#      Cluster                                              Issue
# 165        0                                   Credit reporting
# 134        0                Unsolicited issuance of credit card
# 123        0                               Credit determination
# 121        0           Unable to get credit report/credit score
# 111        0                     Credit decision / Underwriting
# 79         0         Problem with credit report or credit score
# 67         0                               Credit limit changed
# 25         0   Unable to get your credit report or credit score
# 113        1              Managing, opening, or closing account
# 30         1                                 Opening an account
# 22         1  Managing, opening, or closing your mobile wall...
# 18         1                                Managing an account
# 50         2                        Struggling to pay your bill
# 16         2                         Struggling to pay mortgage
# 0          2                        Struggling to pay your loan
# 62         3                      Problem with customer service
# 130        3                Customer service/Customer relations
# 138        3              Customer service / Customer relations
# 72         4                                        Advertising
# 12         4   Confusing or misleading advertising or marketing
# 47         4  Advertising and marketing, including promotion...
# 124        4                          Advertising and marketing
# 127        4              Advertising, marketing or disclosures
# 162        5                                 Repaying your loan
# 110        5                                Can't repay my loan

# %% [markdown]
# ### Snapshot of Clusters with Issue and Value Counts

# %%
for cluster in range(50):
    print(cluster_df.loc[cluster_df['Cluster'] == cluster].head(3), 
          len(cluster_df.loc[cluster_df['Cluster'] == cluster]))
# Out:
#      Cluster                                Issue
# 165        0                     Credit reporting
# 134        0  Unsolicited issuance of credit card
# 123        0                 Credit determination 8
#      Cluster                                              Issue
# 113        1              Managing, opening, or closing account
# 30         1                                 Opening an account
# 22         1  Managing, opening, or closing your mobile wall... 4
#     Cluster                        Issue
# 50        2  Struggling to pay your bill
# 16        2   Struggling to pay mortgage
# 0         2  Struggling to pay your loan 3
#      Cluster                                  Issue
# 62         3          Problem with customer service
# 130        3    Customer service/Customer relations
# 138        3  Customer service / Customer relations 3
#     Cluster                                              Issue
# 72        4                                        Advertising
# 12        4   Confusing or misleading advertising or marketing
# 47        4  Advertising and marketing, including promotion... 5
#      Cluster                          Issue
# 162        5             Repaying your loan
# 110        5            Can't repay my loan
# 21         5  Struggling to repay your loan 3
#     Cluster                      Issue
# 39        6    Trouble using your card
# 59        6     Trouble using the card
# 82        6  Using a debit or ATM card 3
#      Cluster                                              Issue
# 147        7                                 Convenience checks
# 13         7                              Communication tactics
# 55         7  Problem with additional add-on products or ser... 14
#      Cluster          Issue
# 106        8      Other fee
# 154        8  Overlimit fee
# 116        8       Late fee 3
#     Cluster                                              Issue
# 28        9  Applying for a mortgage or refinancing an exis...
# 66        9                            Applying for a mortgage
# 52        9                              Closing on a mortgage 3
#     Cluster                       Issue
# 26       10        Closing your account
# 99       10  Closing/Cancelling account
# 41       10          Closing an account 5
#      Cluster                     Issue
# 80        11         Property was sold
# 161       11  Lender sold the property 2
#      Cluster                                       Issue
# 126       12    Charged fees or interest I didn't expect
# 37        12  Charged fees or interest you didn't expect 2
#      Cluster                  Issue
# 70        13         Excessive fees
# 157       13                   Fees
# 152       13  Unexpected/Other fees 5
#     Cluster                                   Issue
# 84       14  Incorrect information on credit report
# 3        14    Incorrect information on your report 2
#      Cluster                                         Issue
# 133       15        Lender repossessed or sold the vehicle
# 68        15  Vehicle was damaged or destroyed the vehicle
# 48        15   Vehicle was repossessed or sold the vehicle 3
#      Cluster                      Issue
# 74        16  Problem with cash advance
# 158       16               Cash advance
# 156       16           Cash advance fee 3
#     Cluster                                 Issue
# 92       17    Dealing with my lender or servicer
# 23       17  Dealing with your lender or servicer 2
#      Cluster                                 Issue
# 141       18    Received a loan I didn't apply for
# 33        18  Received a loan you didn't apply for 2
#      Cluster                                    Issue
# 119       19                                  Rewards
# 77        19  Overdraft, savings, or rewards features
# 155       19   Overdraft, savings or rewards features 3
#      Cluster                                              Issue
# 54        20  Credit monitoring or identity theft protection...
# 102       20           Credit monitoring or identity protection
# 56        20  Identity theft protection or other monitoring ... 3
#      Cluster                                              Issue
# 19        21  Unauthorized transactions or other transaction...
# 114       21                                  Transaction issue
# 11        21                          Other transaction problem 4
#      Cluster                                              Issue
# 64        22                   Wrong amount charged or received
# 71        22  Money was taken from your bank account on the ...
# 137       22                 Charged bank acct wrong day or amt 3
#      Cluster                                       Issue
# 159       23         Lender damaged or destroyed vehicle
# 160       23        Lender damaged or destroyed property
# 81        23  Property was damaged or destroyed property 3
#      Cluster                          Issue
# 34        24       Getting a line of credit
# 150       24  Shopping for a line of credit
# 149       24    Managing the line of credit 4
#     Cluster                                   Issue
# 96       25   Problems caused by my funds being low
# 8        25  Problem caused by your funds being low 2
#      Cluster                                              Issue
# 65        26  Was approved for a loan, but didn't receive money
# 129       26             Applied for loan/did not receive money
# 61        26  Was approved for a loan, but didn't receive th... 3
#      Cluster                                  Issue
# 128       27                            Disclosures
# 10        27       Confusing or missing disclosures
# 107       27  Incorrect/missing disclosures or info 3
#     Cluster                                              Issue
# 14       28                     Trouble during payment process
# 89       28                       Settlement process and costs
# 35       28  Problem with the payoff process at the end of ... 4
#     Cluster                    Issue
# 32       29  Getting a loan or lease
# 60       29           Getting a loan
# 53       29    Getting a credit card 4
#     Cluster                       Issue
# 73       30  Lost or stolen money order
# 69       30        Lost or stolen check 2
#      Cluster                                         Issue
# 142       31                  Payment to acct not credited
# 46        31  Loan payment wasn't credited to your account 2
#     Cluster                                              Issue
# 5        32  Problem with a credit reporting company's inve...
# 27       32  Problem with a company's investigation into an...
# 93       32           Credit reporting company's investigation 3
#      Cluster                                            Issue
# 9         33  Problem with a purchase shown on your statement
# 100       33                                 Billing disputes
# 115       33                                Billing statement 3
#     Cluster                      Issue
# 78       34     Problem with overdraft
# 75       34  Problem with an overdraft 2
#      Cluster                             Issue
# 6         35       Improper use of your report
# 118       35  Improper use of my credit report 2
#     Cluster                                  Issue
# 4        36      Attempts to collect debt not owed
# 94       36  Cont'd attempts collect debt not owed 2
#      Cluster                                     Issue
# 17        37              Problem when making payments
# 122       37  Making/receiving payments, sending money
# 86        37  Loan servicing, payments, escrow account 3
#      Cluster                                     Issue
# 90        38  Loan modification,collection,foreclosure
# 163       38                      Collection practices
# 164       38                   Collection debt dispute 3
#      Cluster                 Issue
# 36        39  Problem adding money
# 151       39          Adding money 2
#      Cluster                                     Issue
# 7         40                Managing the loan or lease
# 117       40              Shopping for a loan or lease
# 29        40  Problems at the end of the loan or lease 4
#      Cluster                                Issue
# 140       41                 Balance transfer fee
# 31        41  Problem with a purchase or transfer
# 139       41                     Balance transfer 3
#      Cluster                                          Issue
# 24        42                                  Fraud or scam
# 40        42  Problem with fraud alerts or security freezes
# 103       42          Identity theft / Fraud / Embezzlement 3
#      Cluster                                    Issue
# 136       43                     Other service issues
# 38        43                    Other service problem
# 125       43  Unauthorized transactions/trans. issues 3
#      Cluster                                          Issue
# 58        44  Can't stop withdrawals from your bank account
# 135       44             Can't stop charges to bank account
# 91        44                       Deposits and withdrawals 3
#      Cluster                    Issue
# 120       45     APR or interest rate
# 76        45  Incorrect exchange rate 2
#      Cluster                                Issue
# 51        46   Other features, terms, or problems
# 104       46  Problems when you are unable to pay 2
#      Cluster                                     Issue
# 2         47           Written notification about debt
# 108       47  Credit card protection / Debt protection
# 95        47           Disclosure verification of debt 3
#      Cluster                                Issue
# 63        48     Can't contact lender or servicer
# 97        48  Improper contact or sharing of info
# 112       48                 Can't contact lender 4
#      Cluster                                              Issue
# 42        49  Problem with a lender or other company chargin...
# 87        49                                 Delinquent account
# 143       49                          Account terms and changes 4

# %%
cluster_df[cluster_df['Cluster']==7]
# Out:
#      Cluster                                              Issue
# 147        7                                 Convenience checks
# 13         7                              Communication tactics
# 55         7  Problem with additional add-on products or ser...
# 85         7                                              Other
# 88         7           Application, originator, mortgage broker
# 105        7               Taking/threatening an illegal action
# 20         7  Took or threatened to take negative or legal a...
# 153        7                                            Privacy
# 44         7              Money was not available when promised
# 131        7                       Application processing delay
# 148        7                                         Bankruptcy
# 1          7                 False statements or representation
# 146        7                        Forbearance / Workout plans
# 145        7                                        Arbitration

# %%
df = master_df.merge(cluster_df, how='inner', on='Issue')

# %%
df['Cluster'].value_counts()
# Out:
# 14    274762
# 7     117426
# 38    114212
# 36    112971
# 37     91391
# 32     81810
# 47     61050
# 10     54725
# 35     44266
# 28     39825
# 1      37886
# 33     31751
# 17     31710
# 0      29562
# 40     29186
# 2      27199
# 44     23578
# 42     21505
# 5      18177
# 46     16865
# 25     15981
# 48     14623
# 9       9819
# 6       9184
# 13      9041
# 29      8904
# 20      8186
# 49      7881
# 21      7524
# 4       6991
# 8       6052
# 12      5581
# 45      5571
# 3       4333
# 24      3719
# 19      2986
# 41      2627
# 43      2487
# 22       989
# 18       881
# 27       705
# 31       645
# 16       484
# 26       459
# 39       332
# 30       272
# 15       250
# 34        23
# 23        14
# 11        12
# Name: Cluster, dtype: int64

# %%
df[df['Cluster']==2].head()
# Out:
#   Date received                                    Product       Sub-product  \
# 0    10/01/2019  Payday loan, title loan, or personal loan  Installment loan
# 1    09/29/2019  Payday loan, title loan, or personal loan        Title loan
# 2    09/27/2019                      Vehicle loan or lease              Loan
# 3    09/27/2019  Payday loan, title loan, or personal loan  Installment loan
# 4    09/25/2019                      Vehicle loan or lease              Loan
#
#                          Issue  \
# 0  Struggling to pay your loan
# 1  Struggling to pay your loan
# 2  Struggling to pay your loan
# 3  Struggling to pay your loan
# 4  Struggling to pay your loan
#
#                                            Sub-issue  \
# 0                                                NaN
# 1                                                NaN
# 2  Lender trying to repossess or disable the vehicle
# 3                                                NaN
# 4  Lender trying to repossess or disable the vehicle
#
#   Consumer complaint narrative  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              Company public response  \
# 0  Company believes it acted appropriately as aut...
# 1                                                NaN
# 2                                                NaN
# 3  Company believes it acted appropriately as aut...
# 4  Company believes it acted appropriately as aut...
#
#                            Company State ZIP code Tags  \
# 0       Atlas Credit Company, Inc.    TX    75703  NaN
# 1       CURO Intermediate Holdings    AZ      NaN  NaN
# 2        NAVY FEDERAL CREDIT UNION    CA    92324  NaN
# 3       Atlas Credit Company, Inc.    TX    75703  NaN
# 4  American Credit Acceptance, LLC    MD    20706  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           10/01/2019
# 1                        NaN           Web           09/29/2019
# 2                        NaN      Referral           09/28/2019
# 3       Consent not provided           Web           09/27/2019
# 4                        NaN         Phone           09/25/2019
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2                  In progress              Yes                NaN
# 3      Closed with explanation              Yes                NaN
# 4      Closed with explanation              Yes                NaN
#
#    Complaint ID  Cluster
# 0       3391722        2
# 1       3389959        2
# 2       3389309        2
# 3       3388210        2
# 4       3385477        2
