# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###  1. Find the url for the mtcars dataset from the following website:
#
# https://vincentarelbundock.github.io/Rdatasets/datasets.html
#
# Read through the "DOC" file to understand the variables in the dataset, then use the following url to import the data using pandas read_csv function.

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv")

# %% [markdown]
# ### 2.  Display the first five rows of the data.

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ###  3.Calculate the average of the mpg column for all cars within each category of the cyl column.

# %%
df_rank = df.groupby(['mpg'])

# %%
df_rank.mean()
# Out:
#       cyl   disp     hp   drat     wt   qsec   vs   am  gear  carb
# mpg
# 10.4  8.0  466.0  210.0  2.965  5.337  17.90  0.0  0.0   3.0   4.0
# 13.3  8.0  350.0  245.0  3.730  3.840  15.41  0.0  0.0   3.0   4.0
# 14.3  8.0  360.0  245.0  3.210  3.570  15.84  0.0  0.0   3.0   4.0
# 14.7  8.0  440.0  230.0  3.230  5.345  17.42  0.0  0.0   3.0   4.0
# 15.0  8.0  301.0  335.0  3.540  3.570  14.60  0.0  1.0   5.0   8.0
# ...   ...    ...    ...    ...    ...    ...  ...  ...   ...   ...
# 26.0  4.0  120.3   91.0  4.430  2.140  16.70  0.0  1.0   5.0   2.0
# 27.3  4.0   79.0   66.0  4.080  1.935  18.90  1.0  1.0   4.0   1.0
# 30.4  4.0   85.4   82.5  4.350  1.564  17.71  1.0  1.0   4.5   2.0
# 32.4  4.0   78.7   66.0  4.080  2.200  19.47  1.0  1.0   4.0   1.0
# 33.9  4.0   71.1   65.0  4.220  1.835  19.90  1.0  1.0   4.0   1.0
#
# [25 rows x 10 columns]

# %%
df.groupby('mpg')[['cyl']].mean()
# Out:
#       cyl
# mpg
# 10.4    8
# 13.3    8
# 14.3    8
# 14.7    8
# 15.0    8
# ...   ...
# 26.0    4
# 27.3    4
# 30.4    4
# 32.4    4
# 33.9    4
#
# [25 rows x 1 columns]

# %%
df.groupby('mpg')[['cyl']].mean()
# Out:
#       cyl
# mpg
# 10.4    8
# 13.3    8
# 14.3    8
# 14.7    8
# 15.0    8
# ...   ...
# 26.0    4
# 27.3    4
# 30.4    4
# 32.4    4
# 33.9    4
#
# [25 rows x 1 columns]

# %%
pd.set_option('display.max_rows', 10)

# %%
df.groupby('mpg')[['cyl']].mean()
# Out:
#       cyl
# mpg
# 10.4    8
# 13.3    8
# 14.3    8
# 14.7    8
# 15.0    8
# ...   ...
# 26.0    4
# 27.3    4
# 30.4    4
# 32.4    4
# 33.9    4
#
# [25 rows x 1 columns]

# %% [markdown]
# ### 4.Create a histogram using the mpg column

# %%
plt.hist(mpg)
plt.show()

# %% [markdown]
# ### 5. Choose two variables in the data and create a scatterplot.

# %%
plt.scatter(mpg, hp)  
plt.show()
